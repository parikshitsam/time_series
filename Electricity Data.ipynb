# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.tsa.stattools as tsa
# %matplotlib notebook

# %%
path = r"C:\Users\parik\Documents\Data sets\elecprices.csv"
df = pd.read_csv(path)
df.set_index("Year",inplace=True)
df.head()
# Out:
#       Price
# Year
# 1948    3.1
# 1949    3.2
# 1950    3.3
# 1951    3.5
# 1952    3.8

# %%
# df = df[90-48:]
plt.figure()
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Year'>

# %%
df['lnprice'] = np.log(df)

# %%
plt.figure()
df['diff'] = df['lnprice'].diff(periods=1)
df["diff"].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <AxesSubplot:xlabel='Year'>

# %%
adstat, pvalue, used_lag,*rest = tsa.adfuller(df['diff'][1:])
print("adfstat: ",adstat, "     ", "Pvalue: ", pvalue, "     ", "Num Lags: ",used_lag)
# Out:
# adfstat:  -1.9814149236320542       Pvalue:  0.2947809858975431       Num Lags:  5
